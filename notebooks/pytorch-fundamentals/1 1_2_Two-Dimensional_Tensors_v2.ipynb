# %% [markdown]
# <h1>İki Boyutlu Tensörler</h1>

# %% [markdown]
# <h2>Amaç</h2><ul><li> 2 boyutlu tensörler üzerinde tensör işlemleri nasıl gerçekleştirilir?</li></ul>

# %%
# %%time
# %pip install torch==2.8.0+cpu torchvision==0.23.0+cpu torchaudio==2.8.0+cpu \
    --index-url https://download.pytorch.org/whl/cpu
# %pip install numpy pandas matplotlib
# Out:
# Looking in indexes: https://download.pytorch.org/whl/cpu
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 183.9/183.9 MB 52.9 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 93.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 101.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.1/7.1 MB 61.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 50.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 81.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.6/16.6 MB 46.8 MB/s eta 0:00:00:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 536.2/536.2 kB 29.3 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.9/10.9 MB 164.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.8/8.8 MB 148.3 MB/s eta 0:00:00
# ...

# %% [markdown]
# ## Please restart the kernel to use updated packages

# %%
# These are the libraries will be used for this lab.

import numpy as np 
import matplotlib.pyplot as plt
import torch
import pandas as pd

# %% [markdown]
# <!--Empty Space for separating topics-->

# %% [markdown]
# <h2 id="Types_Shape">Türler ve Şekil</h2>

# %% [markdown]
# 2 boyutlu tensörler için kullanılan yöntemler ve türler, <i>Önceki Laboratuvar</i>da tanıtılan 1 boyutlu tensörler için kullanılan yöntemler ve türlere benzerdir.

# %% [markdown]
# İki boyutlu bir listeyi iki boyutlu bir tensöre nasıl dönüştüreceğimizi görelim. Öncelikle 3x3'lük iki boyutlu bir tensör oluşturalım. Ardından, tek boyutlu bir listeyi tek boyutlu bir tensöre dönüştürmek için kullandığımız `<code>torch.tensor()</code>` yöntemini kullanmayı deneyelim. Çalışacak mı?

# %%
# Convert 2D List to 2D Tensor

twoD_list = [[11, 12, 13], [21, 22, 23], [31, 32, 33]]
twoD_tensor = torch.tensor(twoD_list)
print("The New 2D Tensor: ", twoD_tensor)
# Out:
# The New 2D Tensor:  tensor([[11, 12, 13],
#         [21, 22, 23],
#         [31, 32, 33]])

# %% [markdown]
# Bravo! <code>torch.tensor()</code> metodu mükemmel çalışıyor. Şimdi, <i>Önceki Laboratuvarda</i> incelediğimiz diğer fonksiyonları deneyelim.

# %% [markdown]
# <!--Empty Space for separating topics-->

# %% [markdown]
# <code><i>tensor_obj</i>.ndimension()</code> (<code>tensor_obj</code>: Bu herhangi bir tensör nesnesi olabilir), <code><i>tensor_obj</i>.shape</code> ve <code><i>tensor_obj</i>.size()</code> fonksiyonlarını deneyelim.

# %%
# tensor_obj.ndimension(), tensor_obj.shape, tensor_obj.size() fonksiyonlarını deneyin

print("twoD_tensor'ın boyutu: ", twoD_tensor.ndimension())
print("twoD_tensor'ın şekli: ", twoD_tensor.size())
print("twoD_tensor'daki eleman sayısı: ", twoD_tensor.numel())
# Out:
# twoD_tensor'ın boyutu:  2
# twoD_tensor'ın şekli:  torch.Size([3, 3])
# twoD_tensor'daki eleman sayısı:  9

# %% [markdown]
# 2 boyutlu 3x3 bir tensör olduğu için çıktılar doğrudur.

# %% [markdown]
# <!--Empty Space for separating topics-->

# %% [markdown]
# Şimdi, tensörü bir NumPy dizisine dönüştürmeyi ve NumPy dizisini tekrar tensöre dönüştürmeyi deneyelim.

# %%
# Convert tensor to numpy array; Convert numpy array to tensor

twoD_numpy = twoD_tensor.numpy()
print("Tensor -> Numpy Array:")
print("The numpy array after converting: ", twoD_numpy)
print("Type after converting: ", twoD_numpy.dtype)

print("================================================")

new_twoD_tensor = torch.from_numpy(twoD_numpy)
print("Numpy Array -> Tensor:")
print("The tensor after converting:", new_twoD_tensor)
print("Type after converting: ", new_twoD_tensor.dtype)
# Out:
# Tensor -> Numpy Array:
# The numpy array after converting:  [[11 12 13]
#  [21 22 23]
#  [31 32 33]]
# Type after converting:  int64
# ...
# Numpy Array -> Tensor:
# The tensor after converting: tensor([[11, 12, 13],
#         [21, 22, 23],
#         [31, 32, 33]])
# Type after converting:  torch.int64

# %% [markdown]
# Sonuç, tensörün başarıyla bir numpy dizisine dönüştürüldüğünü ve ardından tekrar tensöre dönüştürüldüğünü göstermektedir.

# %% [markdown]
# <!--Empty Space for separating topics-->

# %% [markdown]
# Şimdi bir Pandas DataFrame'i tensöre dönüştürmeyi deneyelim. İşlem, 1 boyutlu dönüştürmeyle aynıdır; `<code>values</code>` özniteliği aracılığıyla numpy dizisini elde edebiliriz. Ardından, Pandas Series'in değerini tensöre dönüştürmek için `<code>torch.from_numpy()</code>` kullanabiliriz.

# %%
# Try to convert the Panda Dataframe to tensor

df = pd.DataFrame({'a':[11,21,31],'b':[12,22,312]})

print("Pandas Dataframe to numpy: ", df.values)
print("Type BEFORE converting: ", df.values.dtype)

print("================================================")

new_tensor = torch.from_numpy(df.values)
print("Tensor AFTER converting: ", new_tensor)
print("Type AFTER converting: ", new_tensor.dtype)
# Out:
# Pandas Dataframe to numpy:  [[ 11  12]
#  [ 21  22]
#  [ 31 312]]
# Type BEFORE converting:  int64
# ...
# Tensor AFTER converting:  tensor([[ 11,  12],
#         [ 21,  22],
#         [ 31, 312]])
# Type AFTER converting:  torch.int64
# /tmp/ipykernel_300/292995214.py:10: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at /pytorch/torch/csrc/utils/tensor_numpy.cpp:203.)
#   new_tensor = torch.from_numpy(df.values)

# %% [markdown]
# <!--Empty Space for separating topics-->

# %% [markdown]
# <!--Empty Space for separating topics-->

# %% [markdown]
# <h3>Practice</h3>

# %% [markdown]
# Try to convert the following Pandas Dataframe  to a tensor

# %%
# Practice: try to convert Pandas Series to tensor

df = pd.DataFrame({'A':[11, 33, 22],'B':[3, 3, 2]})
converted_tensor = torch.tensor(df.values)
print ("Tensor: ", converted_tensor)
# Out:
# Tensor:  tensor([[11,  3],
#         [33,  3],
#         [22,  2]])

# %% [markdown]
# <h2 id="Index_Slice">İndeksleme ve Dilimleme</h2>

# %% [markdown]
# Tensörün farklı elemanlarına erişmek için dikdörtgen parantezleri kullanabilirsiniz. Dikdörtgen parantezler ile liste ve dikdörtgen gösterim arasındaki ilişki, 3x3'lük bir tensör için aşağıdaki şekilde gösterilmiştir:

# %% [markdown]
# <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/DL0110EN/notebook_images%20/chapter%201/1.2index1.png" width="500" alt="Matrix Structure Introduce">

# %% [markdown]
# You can access the 2nd-row 3rd-column as shown in the following figure:

# %% [markdown]
# <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/DL0110EN/notebook_images%20/chapter%201/1.2index.png" width="500" alt="Example of Matrix Index">

# %% [markdown]
# Köşeli parantezleri ve istediğiniz öğeye karşılık gelen indeksleri kullanmanız yeterlidir.

# %% [markdown]
# Şimdi, 2. satır 3. sütundaki değere erişmeyi deneyelim. Unutmayın ki indeks her zaman satır ve sütun sayımından 1 eksiktir. Bir tensörün belirli bir değerine erişmenin iki yolu vardır. Koddaki örnek, yukarıdaki örnek resimle aynı olacaktır.

# %%
# Use tensor_obj[row, column] and tensor_obj[row][column] to access certain position

tensor_example = torch.tensor([[11, 12, 13], [21, 22, 23], [31, 32, 33]])
print("What is the value on 2nd-row 3rd-column? ", tensor_example[1, 2])
print("What is the value on 2nd-row 3rd-column? ", tensor_example[1][2])
# Out:
# What is the value on 2nd-row 3rd-column?  tensor(23)
# What is the value on 2nd-row 3rd-column?  tensor(23)

# %% [markdown]
# Gördüğümüz gibi, her iki yöntem de doğru değeri (yukarıdaki resimdekiyle aynı değeri) döndürüyor. Bu nedenle, her iki yöntem de çalışıyor.

# %% [markdown]
# <!--Empty Space for separating topics-->

# %% [markdown]
# Consider the elements shown in the following figure:

# %% [markdown]
# <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/DL0110EN/notebook_images%20/chapter%201/1.2_index2.png" width="500" alt="Example of Matrix Index">

# %% [markdown]
# Use the method above, we can access the 1st-row 1st-column by <code>tensor_example[0][0]</code>

# %%
tensor_example[0][0]
# Out:
# tensor(11)

# %% [markdown]
# Peki ya hem 1. satır 1. sütundaki hem de 1. satır 2. sütundaki değeri almak istersek ne olacak?

# %% [markdown]
# Tensörlerde dilimleme işlemini de kullanabilirsiniz. Aşağıdaki şekli ele alalım. Birinci satırdaki ilk iki sütunu elde etmek istiyorsunuz:

# %% [markdown]
# <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/DL0110EN/notebook_images%20/chapter%201/1.2sliceing.png" width="500" alt="Example of Matrix Index and Slicing">

# %% [markdown]
# ## Let us see how  we use slicing with 2D tensors to get the values in the above picture.

# %%
# Use tensor_obj[begin_row_number: end_row_number, begin_column_number: end_column number] 
# and tensor_obj[row][begin_column_number: end_column number] to do the slicing

tensor_example = torch.tensor([[11, 12, 13], [21, 22, 23], [31, 32, 33]])
print("What is the value on 1st-row first two columns? ", tensor_example[0, 0:2])
print("What is the value on 1st-row first two columns? ", tensor_example[0][0:2])
# Out:
# What is the value on 1st-row first two columns?  tensor([11, 12])
# What is the value on 1st-row first two columns?  tensor([11, 12])

# %% [markdown]
# We get the result as <code>tensor([11, 12])</code> successfully.

# %% [markdown]
# <!--Empty Space for separating topics-->

# %% [markdown]
# Ancak, <code>tensor_obj[begin_row_number: end_row_number][begin_column_number: end_column_number]</code> kodunu kullanarak satır üzerinde dilimleme yapıp tek bir sütun seçemeyiz. Bunun nedeni, dilimlemenin önce tensöre uygulanacak olmasıdır. Sonuç türü yine iki boyutlu olacaktır. İkinci parantez artık sütun indeksini değil, o anki satır indeksini temsil edecektir. Bir örnek görelim.

# %%
# Give an idea on tensor_obj[number: number][number]

tensor_example = torch.tensor([[11, 12, 13], [21, 22, 23], [31, 32, 33]])
sliced_tensor_example = tensor_example[1:3]
print("1. Slicing step on tensor_example: ")
print("Result after tensor_example[1:3]: ", sliced_tensor_example)
print("Dimension after tensor_example[1:3]: ", sliced_tensor_example.ndimension())
print("================================================")
print("2. Pick an index on sliced_tensor_example: ")
print("Result after sliced_tensor_example[1]: ", sliced_tensor_example[1])
print("Dimension after sliced_tensor_example[1]: ", sliced_tensor_example[1].ndimension())
print("================================================")
print("3. Combine these step together:")
print("Result: ", tensor_example[1:3][1])
print("Dimension: ", tensor_example[1:3][1].ndimension())
# Out:
# 1. Slicing step on tensor_example:
# Result after tensor_example[1:3]:  tensor([[21, 22, 23],
#         [31, 32, 33]])
# Dimension after tensor_example[1:3]:  2
# ...
# 2. Pick an index on sliced_tensor_example:
# Result after sliced_tensor_example[1]:  tensor([31, 32, 33])
# Dimension after sliced_tensor_example[1]:  1
# ...
# 3. Combine these step together:
# Result:  tensor([31, 32, 33])
# Dimension:  1

# %% [markdown]
# See the results and dimensions in 2 and 3 are the same. Both of them contains the 3rd row in the <code>tensor_example</code>, but not the last two values in the 3rd column.

# %% [markdown]
# <!--Empty Space for separating topics-->

# %% [markdown]
# So how can we get the elements in the 3rd column with the last two rows? As the below picture.

# %% [markdown]
# <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/DL0110EN/notebook_images%20/chapter%201/1.2slicing2.png" width="500" alt="Example of Matrix Index and Slicing">

# %% [markdown]
# Let's see the code below.

# %%
# Use tensor_obj[begin_row_number: end_row_number, begin_column_number: end_column number] 

tensor_example = torch.tensor([[11, 12, 13], [21, 22, 23], [31, 32, 33]])
print("What is the value on 3rd-column last two rows? ", tensor_example[1:3, 2])
# Out:
# What is the value on 3rd-column last two rows?  tensor([23, 33])

# %% [markdown]
# Neyse ki, <code>tensor_obj[begin_row_number: end_row_number, begin_column_number: end_column_number]</code> kodu hala çalışıyor.

# %% [markdown]
# <!--Empty Space for separating topics-->

# %% [markdown]
# <h3>Practice</h3>

# %% [markdown]
# İkinci sütundaki ve son iki satırdaki değerleri 0'a değiştirmeyi deneyin. Temel olarak, <code>tensor_ques[1][1]</code> ve <code>tensor_ques[2][1]</code> değerlerini 0'a değiştirin.

# %%
# Practice: Use slice and index to change the values on the matrix tensor_ques.

tensor_ques = torch.tensor([[11, 12, 13], [21, 22, 23], [31, 32, 33]])
tensor_ques[1:3, 1] = 0
print("The result: ", tensor_ques)
# Out:
# The result:  tensor([[11, 12, 13],
#         [21,  0, 23],
#         [31,  0, 33]])

# %% [markdown]
# Double-click <b>here</b> for the solution.
#
# <!--
# tensor_ques[1:3, 1] = 0
# print("The result: ", tensor_ques)
# -->

# %% [markdown]
# <!--Empty Space for separating topics-->

# %% [markdown]
# <h2 id="Tensor_Op">Tensor İşlemleri</h2>

# %% [markdown]
# İki boyutlu tensörler üzerinde de bazı hesaplamalar yapabiliriz.

# %% [markdown]
# <!--Empty Space for separating topics-->

# %% [markdown]
# <h3>Tensor Toplama</h3>

# %% [markdown]
# Tensörleri de toplayabilirsiniz; işlem matris toplama ile aynıdır. <b>X</b> ve <b>Y</b>'nin matris toplaması aşağıdaki şekilde gösterilmiştir:

# %% [markdown]
# <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/DL0110EN/notebook_images%20/chapter%201/1.2add.png" width="500" alt="Tensor Addition in 2D">

# %% [markdown]
# Let us see how tensor addition works with <code>X</code> and <code>Y</code>.

# %%
# Calculate [[1, 0], [0, 1]] + [[2, 1], [1, 2]]

X = torch.tensor([[1, 0],[0, 1]]) 
Y = torch.tensor([[2, 1],[1, 2]])
X_plus_Y = X + Y
print("The result of X + Y: ", X_plus_Y)
# Out:
# The result of X + Y:  tensor([[3, 1],
#         [1, 3]])

# %% [markdown]
# Like the result shown in the picture above. The result is <code>[[3, 1], [1, 3]]</code>

# %% [markdown]
# <!--Empty Space for separating topics-->

# %% [markdown]
# <h3> Scalar Multiplication </h3>

# %% [markdown]
# Multiplying a tensor by a scalar is identical to multiplying a matrix by a scaler. If you multiply the matrix <b>Y</b> by the scalar 2, you simply multiply every element in the matrix by 2 as shown in the figure:

# %% [markdown]
# <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/DL0110EN/notebook_images%20/chapter%201/1.2scaller_mult.png" width="500" alt="The product of tensor and scalar">

# %% [markdown]
# Let us try to calculate the product of <b>2Y</b>.

# %%
# Calculate 2 * [[2, 1], [1, 2]]

Y = torch.tensor([[2, 1], [1, 2]]) 
two_Y = 2 * Y
print("The result of 2Y: ", two_Y)
# Out:
# The result of 2Y:  tensor([[4, 2],
#         [2, 4]])

# %% [markdown]
# <!--Empty Space for separating topics-->

# %% [markdown]
# <h3>Element Bazlı Ürün/Hadamard Ürünü</h3>

# %% [markdown]
# İki tensörün çarpımı, eleman bazında çarpım veya Hadamard çarpımına karşılık gelir. Aynı boyutta olan <b>X</b> ve <b>Y</b> matrislerini ele alalım. Hadamard çarpımı, aynı konumdaki elemanların her birinin çarpımına, yani aynı renkteki elemanların birbirleriyle çarpımına karşılık gelir. Sonuç, aşağıdaki şekilde gösterildiği gibi, <b>X</b> ve <b>Y</b> matrisleriyle aynı boyutta yeni bir matristir:

# %% [markdown]
#  <a><img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/DL0110EN/notebook_images%20/chapter%201/1.2tensor_pruduct.png" width="500" align="center"> </a>

# %% [markdown]
# The code below calculates the element-wise product of the tensor <strong>X</strong> and <strong>Y</strong>:

# %%
# Calculate [[1, 0], [0, 1]] * [[2, 1], [1, 2]]

X = torch.tensor([[1, 0], [0, 1]])
Y = torch.tensor([[2, 1], [1, 2]]) 
X_times_Y = X * Y
print("The result of X * Y: ", X_times_Y)
# Out:
# The result of X * Y:  tensor([[2, 0],
#         [0, 2]])

# %% [markdown]
# This is a simple calculation. The result from the code matches the result shown in the picture.

# %% [markdown]
# <!--Empty Space for separating topics-->

# %% [markdown]
# <h3>Matris Çarpımı</h3>

# %% [markdown]
# İki tensöre matris çarpımı da uygulayabiliriz. Eğer doğrusal cebir öğrendiyseniz, iki matrisin çarpımında sıranın önemli olduğunu bilirsiniz. Yani, <i>X * Y</i> geçerliyse, <i>Y * X</i> de geçerli anlamına gelmez. Çarpım işaretinin sol tarafındaki matrisin sütun sayısı, sağ tarafındaki matrisin satır sayısına eşit olmalıdır.

# %% [markdown]
# Öncelikle, 2x3 boyutunda bir tensör <code>X</code> oluşturalım. Ardından, 3x2 boyutunda başka bir tensör <code>Y</code> oluşturalım. <code>X</code>'in sütun sayısı <code>Y</code>'in satır sayısına eşit olduğundan, çarpma işlemini gerçekleştirebiliriz.

# %% [markdown]
# Farklı boyutlardaki tensörler arasındaki çarpımı hesaplamak için <code>torch.mm()</code> fonksiyonunu kullanıyoruz.

# %%
# Calculate [[0, 1, 1], [1, 0, 1]] * [[1, 1], [1, 1], [-1, 1]]

A = torch.tensor([[0, 1, 1], [1, 0, 1]])
B = torch.tensor([[1, 1], [1, 1], [-1, 1]])
A_times_B = torch.mm(A,B)
print("The result of A * B: ", A_times_B)

# %% [markdown]
# <!--Empty Space for separating topics-->

# %% [markdown]
# <h3>Practice</h3>

# %% [markdown]
# Try to create your own two tensors (<code>X</code> and <code>Y</code>) with different sizes, and multiply them.

# %%
# Practice: Calculate the product of two tensors (X and Y) with different sizes 

# Type your code here

# %% [markdown]
# Double-click <b>here</b> for the solution.
#
# <!--
# X = torch.tensor([[0, 1], [1, 2]])
# Y = torch.tensor([[-1, -2, 0], [2, 1, 2]])
# X_times_Y = torch.mm(X, Y)
# print("The result of X * Y: ", X_times_Y)
# -->

# %% [markdown]
# <!--Empty Space for separating topics-->

# %% [markdown]
# <h2>About the Authors:</h2>
#
# <a href="https://www.linkedin.com/in/joseph-s-50398b136/">Joseph Santarcangelo</a> has a PhD in Electrical Engineering, his research focused on using machine learning, signal processing, and computer vision to determine how videos impact human cognition. Joseph has been working for IBM since he completed his PhD.

# %% [markdown]
# Other contributors: <a href="https://www.linkedin.com/in/michelleccarey/">Michelle Carey</a>, <a href="www.linkedin.com/in/jiahui-mavis-zhou-a4537814a">Mavis Zhou</a>

# %% [markdown]
# <!--
# ## Change Log
#
# |  Date (YYYY-MM-DD) |  Version | Changed By  |  Change Description |
# |---|---|---|---|
# | 2020-09-21  | 2.0  | Shubham  |  Migrated Lab to Markdown and added to course repo in GitLab |
#
# -->

# %% [markdown]
# <hr>

# %% [markdown]
# ## <h3 align="center"> &#169; IBM Corporation. All rights reserved. <h3/>
